# %%
import pandas as pd

# %%
samplesPD = pd.read_json("samples.json")
samplesPD
# Out:
#      names                                           metadata  \
# 0      940  {'id': 940, 'ethnicity': 'Caucasian', 'gender'...
# 1      941  {'id': 941, 'ethnicity': 'Caucasian/Midleaster...
# 2      943  {'id': 943, 'ethnicity': 'Caucasian', 'gender'...
# 3      944  {'id': 944, 'ethnicity': 'European', 'gender':...
# 4      945  {'id': 945, 'ethnicity': 'Caucasian', 'gender'...
# ..     ...                                                ...
# 148   1574  {'id': 1574, 'ethnicity': 'Caucasian', 'gender...
# 149   1576  {'id': 1576, 'ethnicity': 'Caucasian', 'gender...
# 150   1577  {'id': 1577, 'ethnicity': 'Caucasian', 'gender...
# 151   1581  {'id': 1581, 'ethnicity': 'Asian(American)', '...
# 152   1601  {'id': 1601, 'ethnicity': 'Caucasian', 'gender...
#
#                                                samples
# 0    {'id': '940', 'otu_ids': [1167, 2859, 482, 226...
# 1    {'id': '941', 'otu_ids': [2722, 944, 2419, 253...
# ...

# %%
samplesPD.loc[0].samples
# Out:
# {'id': '940',
#  'otu_ids': [1167,
#   2859,
#   482,
#   2264,
#   41,
#   1189,
#   352,
#   189,
#   2318,
#   1977,
#   3450,
#   874,
#   1959,
#   2191,
#   1950,
#   2077,
#   2275,
#   944,
#   2184,
#   2244,
#   2024,
#   2419,
#   2811,
#   165,
#   2782,
#   2247,
#   2011,
#   2396,
#   830,
#   2964,
#   1795,
#   2722,
#   307,
#   2178,
#   2908,
#   1193,
#   2167,
#   1208,
#   2039,
#   1274,
#   2739,
#   2737,
#   1314,
#   1962,
#   2186,
#   2335,
#   2936,
#   907,
#   833,
#   2483,
#   2475,
#   2491,
#   2291,
#   159,
#   2571,
#   2350,
#   2342,
#   2546,
#   725,
#   170,
#   1505,
#   513,
#   259,
#   1169,
#   258,
#   1232,
#   1497,
#   1498,
#   1503,
#   412,
#   2235,
#   1960,
#   1968,
#   121,
#   2065,
#   340,
#   2110,
#   2188,
#   357,
#   342],
#  'sample_values': [163,
#   126,
#   113,
#   78,
#   71,
#   51,
#   50,
#   47,
#   40,
#   40,
#   37,
#   36,
#   30,
#   28,
#   25,
#   23,
#   22,
#   19,
#   19,
#   14,
#   13,
# ...
